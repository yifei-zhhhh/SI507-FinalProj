# %%
import requests
import pandas as pd

# %%
movie_list=pd.read_csv("movie_list.csv")

# %%
title=movie_list["name"]
year=movie_list["year"].astype(str)

# %%
imdb=[]
tomato=[]
metacritic=[]
i=0
movieInfo = requests.get('http://www.omdbapi.com/?apikey='+API_KEY+'&t='+title[i]+'&y='+year[i]).json()
imdb.append(pd.DataFrame(movieInfo)["Ratings"][0].get('Value'))
tomato.append(pd.DataFrame(movieInfo)["Ratings"][1].get('Value'))
metacritic.append(pd.DataFrame(movieInfo)["Ratings"][2].get('Value'))
movie_detail=pd.DataFrame(movieInfo).loc[[0], :]

for i in range(1,250):
    movieInfo = requests.get('http://www.omdbapi.com/?apikey='+API_KEY+'&t='+title[i]+'&y='+year[i]).json()
    try:
        imdb.append(pd.DataFrame(movieInfo)["Ratings"][0].get('Value'))
    except:
        imdb.append("N/A")
    try:
        tomato.append(pd.DataFrame(movieInfo)["Ratings"][1].get('Value'))
    except:
        tomato.append("N/A")
    try:
        metacritic.append(pd.DataFrame(movieInfo)["Ratings"][2].get('Value'))
    except:
        metacritic.append("N/A")
    temp=pd.DataFrame(movieInfo).loc[[0], :]
    movie_detail=pd.concat([movie_detail, temp], ignore_index=True)

# %%
movie_detail
# Out:
#                         Title  Year     Rated     Released  Runtime  \
# 0    The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1               The Godfather  1972         R  24 Mar 1972  175 min
# 2             The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 3       The Godfather Part II  1974         R  18 Dec 1974  202 min
# 4                12 Angry Men  1957  Approved  10 Apr 1957   96 min
# ..                        ...   ...       ...          ...      ...
# 245               Dersu Uzala  1975         G  20 Dec 1977  142 min
# 246                   Aladdin  1992         G  25 Nov 1992   90 min
# 247                  The Help  2011     PG-13  10 Aug 2011  146 min
# 248            The Iron Giant  1999        PG  06 Aug 1999   86 min
# 249                    Gandhi  1982        PG  25 Feb 1983  191 min
#
#                             Genre                   Director  \
# 0                           Drama             Frank Darabont
# 1                    Crime, Drama       Francis Ford Coppola
# 2            Action, Crime, Drama          Christopher Nolan
# 3                    Crime, Drama       Francis Ford Coppola
# 4                    Crime, Drama               Sidney Lumet
# ..                            ...                        ...
# 245   Adventure, Biography, Drama             Akira Kurosawa
# 246  Animation, Adventure, Comedy  Ron Clements, John Musker
# 247                         Drama                Tate Taylor
# 248  Animation, Action, Adventure                  Brad Bird
# 249              Biography, Drama       Richard Attenborough
#
#                                                 Writer  \
# 0                         Stephen King, Frank Darabont
# 1                     Mario Puzo, Francis Ford Coppola
# 2    Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                     Francis Ford Coppola, Mario Puzo
# 4                                        Reginald Rose
# ..                                                 ...
# 245    Akira Kurosawa, Yuriy Nagibin, Vladimir Arsenev
# 246             Ron Clements, John Musker, Ted Elliott
# 247                      Tate Taylor, Kathryn Stockett
# 248               Tim McCanlies, Brad Bird, Ted Hughes
# 249                                        John Briley
#
#                                                 Actors  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1                 Marlon Brando, Al Pacino, James Caan
# 2          Christian Bale, Heath Ledger, Aaron Eckhart
# 3             Al Pacino, Robert De Niro, Robert Duvall
# 4              Henry Fonda, Lee J. Cobb, Martin Balsam
# ..                                                 ...
# 245      Maksim Munzuk, Yuriy Solomin, Mikhail Bychkov
# 246        Scott Weinger, Robin Williams, Linda Larkin
# 247           Viola Davis, Emma Stone, Octavia Spencer
# 248  Eli Marienthal, Harry Connick Jr., Jennifer An...
# 249      Ben Kingsley, John Gielgud, Rohini Hattangadi
#
#                                                   Plot  ... Metascore  \
# 0    Two imprisoned men bond over a number of years...  ...        81
# 1    The aging patriarch of an organized crime dyna...  ...       100
# 2    When the menace known as the Joker wreaks havo...  ...        84
# 3    The early life and career of Vito Corleone in ...  ...        90
# 4    The jury in a New York City murder trial is fr...  ...        96
# ..                                                 ...  ...       ...
# 245  The Russian army sends an explorer on an exped...  ...       N/A
# 246  A kindhearted street urchin and a power-hungry...  ...        86
# 247  An aspiring author during the civil rights mov...  ...        62
# 248  A young boy befriends a giant robot from outer...  ...        85
# 249  The life of the lawyer who became the famed le...  ...        79
#
#     imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0          9.3  2,662,343  tt0111161  movie  21 Dec 1999   $28,767,189
# 1          9.2  1,847,150  tt0068646  movie  11 May 2004  $136,381,073
# 2          9.0  2,638,780  tt0468569  movie  09 Dec 2008  $534,987,076
# 3          9.0  1,265,087  tt0071562  movie  24 May 2005   $47,834,595
# 4          9.0    786,180  tt0050083  movie  04 Mar 2008           N/A
# ..         ...        ...        ...    ...          ...           ...
# 245        8.2     30,160  tt0071411  movie  22 Mar 2007           N/A
# 246        8.0    420,013  tt0103639  movie  13 Oct 2015  $217,350,219
# 247        8.1    459,753  tt1454029  movie  06 Dec 2011  $169,708,112
# 248        8.1    198,212  tt0129167  movie  27 Sep 2005   $23,315,035
# 249        8.1    232,139  tt0083987  movie  20 Feb 2007   $52,767,889
#
#     Production Website Response
# 0          N/A     N/A     True
# 1          N/A     N/A     True
# 2          N/A     N/A     True
# 3          N/A     N/A     True
# 4          N/A     N/A     True
# ..         ...     ...      ...
# 245        N/A     N/A     True
# 246        N/A     N/A     True
# 247        N/A     N/A     True
# 248        N/A     N/A     True
# 249        N/A     N/A     True
#
# [250 rows x 25 columns]

# %%
metacritic[226]=tomato[226]
tomato[226]="N/A"
metacritic[195]=tomato[195]
tomato[195]="N/A"

# %%
movieInfo
# Out:
# {'Title': 'Gandhi',
#  'Year': '1982',
#  'Rated': 'PG',
#  'Released': '25 Feb 1983',
#  'Runtime': '191 min',
#  'Genre': 'Biography, Drama',
#  'Director': 'Richard Attenborough',
#  'Writer': 'John Briley',
#  'Actors': 'Ben Kingsley, John Gielgud, Rohini Hattangadi',
#  'Plot': 'The life of the lawyer who became the famed leader of the Indian revolts against the British rule through his philosophy of nonviolent protest.',
#  'Language': 'English, Hindi',
#  'Country': 'United Kingdom, India, United States, South Africa',
#  'Awards': 'Won 8 Oscars. 35 wins & 21 nominations total',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOGVmZGU2M2EtZTVjYy00OWU2LWI0YjEtZjQ4YjNmODhmMzhkXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '89%'},
#   {'Source': 'Metacritic', 'Value': '79/100'}],
#  'Metascore': '79',
#  'imdbRating': '8.1',
#  'imdbVotes': '232,139',
#  'imdbID': 'tt0083987',
#  'Type': 'movie',
#  'DVD': '20 Feb 2007',
#  'BoxOffice': '$52,767,889',
#  'Production': 'N/A',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
movie_detail["IMDB"]=pd.DataFrame(imdb)
movie_detail["Rotten Tomatoes"]=pd.DataFrame(tomato)
movie_detail["Metacritic"]=pd.DataFrame(metacritic)

# %%
movie_detail.to_csv("raw_movie_info.csv",index=False)
